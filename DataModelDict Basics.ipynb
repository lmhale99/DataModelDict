# %% [markdown]
# #DataModelDict Class Demonstration
#
# The DataModelDict class is a utility tool for working with structured data models.  It handles the conversions between equivalent representations of json, XML and Python dictionaries.  It also has a few methods associated with checking the data model type and recursively retrieving elements from the model.
#
# Simple examples are presented here to demonstrate the basic functionality of the class.  Full documentation can be found on the [Documentation webpage](Documentation.html).

# %% [markdown]
# Library imports

# %%
#standard Python libraries
import random
import os

#DataModelDict class
from DataModelDict import DataModelDict

# %% [markdown]
# ##1. Class Basics
#
# The DataModelDict is a child class of OrderedDict.  As such, is has all the functionality of OrderedDict and more.
#
# Here, we construct a multi-level demonstration data model using lists and DataModelDicts.

# %%
#Create an empty DataModel
model = DataModelDict()

#Create tiered dictionary for demonstration purposes
model['my-data-model'] = DataModelDict()

model['my-data-model']['name'] = 'Demo'

model['my-data-model']['author'] = 'Me'

model['my-data-model']['process'] = DataModelDict()
model['my-data-model']['process']['Instrument'] = DataModelDict()
model['my-data-model']['process']['Instrument']['Name'] = 'Shiny Thing'
model['my-data-model']['process']['Instrument']['Model'] = 'Newest Most Expensive'
model['my-data-model']['process']['method'] = 'By the book'

#Assign random data for each temperature measurement
model['my-data-model']['measurement'] = []
for temperature in xrange(0, 2000, 50):
    measurement = DataModelDict([('temperature', DataModelDict([('value', temperature),
                                                                ('unit', 'K')])),
                                 ('length',      DataModelDict([('value', temperature*random.random()/50),
                                                                ('unit', 'm')]))])
    model['my-data-model']['measurement'].append(measurement)

# %% [markdown]
# ##2. Output Conversion
#
# DataModelDict has methods json() and xml() that return the data model as either of these formats.

# %%
#Save DataModelDict as json file by setting fp = file-like object
with open('model.json', 'w') as f:
    model.json(fp=f)

#Print the DataModelDict as a json string. 
#Setting an indent value adds newlines and line indentations
print model.json(indent=2)
# Out:
# {
#   "my-data-model": {
#     "name": "Demo",
#     "author": "Me",
#     "process": {
#       "Instrument": {
#         "Name": "Shiny Thing",
#         "Model": "Newest Most Expensive"
#       },
#       "method": "By the book"
#     },
#     "measurement": [
#       {
#         "temperature": {
#           "value": 0,
#           "unit": "K"
#         },
#         "length": {
#           "value": 0.0,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 50,
#           "unit": "K"
#         },
#         "length": {
#           "value": 0.39986098996123576,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 100,
#           "unit": "K"
#         },
#         "length": {
#           "value": 0.7350887664271208,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 150,
#           "unit": "K"
#         },
#         "length": {
#           "value": 2.6241863863073105,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 200,
#           "unit": "K"
#         },
#         "length": {
#           "value": 2.7821708998501165,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 250,
#           "unit": "K"
#         },
#         "length": {
#           "value": 4.726741077367031,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 300,
#           "unit": "K"
#         },
#         "length": {
#           "value": 5.739600147226294,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 350,
#           "unit": "K"
#         },
#         "length": {
#           "value": 1.3136992202639524,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 400,
#           "unit": "K"
#         },
#         "length": {
#           "value": 3.775478992818595,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 450,
#           "unit": "K"
#         },
#         "length": {
#           "value": 1.6292075498700629,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 500,
#           "unit": "K"
#         },
#         "length": {
#           "value": 8.937033340067753,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 550,
#           "unit": "K"
#         },
#         "length": {
#           "value": 10.746507110396685,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 600,
#           "unit": "K"
#         },
#         "length": {
#           "value": 8.242033341633316,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 650,
#           "unit": "K"
#         },
#         "length": {
#           "value": 10.567668172212647,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 700,
#           "unit": "K"
#         },
#         "length": {
#           "value": 12.305571507602233,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 750,
#           "unit": "K"
#         },
#         "length": {
#           "value": 1.4502698012872686,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 800,
#           "unit": "K"
#         },
#         "length": {
#           "value": 4.033322751927717,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 850,
#           "unit": "K"
#         },
#         "length": {
#           "value": 7.355261000046035,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 900,
#           "unit": "K"
#         },
#         "length": {
#           "value": 13.79692538142339,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 950,
#           "unit": "K"
#         },
#         "length": {
#           "value": 16.062783315621484,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1000,
#           "unit": "K"
#         },
#         "length": {
#           "value": 9.678916059061535,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1050,
#           "unit": "K"
#         },
#         "length": {
#           "value": 15.08799736159959,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1100,
#           "unit": "K"
#         },
#         "length": {
#           "value": 1.3465121728657292,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1150,
#           "unit": "K"
#         },
#         "length": {
#           "value": 4.697804719217939,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1200,
#           "unit": "K"
#         },
#         "length": {
#           "value": 9.54570938141391,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1250,
#           "unit": "K"
#         },
#         "length": {
#           "value": 13.736695437676387,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1300,
#           "unit": "K"
#         },
#         "length": {
#           "value": 2.954255730222946,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1350,
#           "unit": "K"
#         },
#         "length": {
#           "value": 26.595459851374873,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1400,
#           "unit": "K"
#         },
#         "length": {
#           "value": 4.791723128290514,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1450,
#           "unit": "K"
#         },
#         "length": {
#           "value": 17.289926505564623,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1500,
#           "unit": "K"
#         },
#         "length": {
#           "value": 8.985074753494507,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1550,
#           "unit": "K"
#         },
#         "length": {
#           "value": 4.253037162747188,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1600,
#           "unit": "K"
#         },
#         "length": {
#           "value": 22.12879115480489,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1650,
#           "unit": "K"
#         },
#         "length": {
#           "value": 22.175456114239356,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1700,
#           "unit": "K"
#         },
#         "length": {
#           "value": 24.200213745881808,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1750,
#           "unit": "K"
#         },
#         "length": {
#           "value": 5.684011678165808,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1800,
#           "unit": "K"
#         },
#         "length": {
#           "value": 8.930905362572705,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1850,
#           "unit": "K"
#         },
#         "length": {
#           "value": 1.763515667806887,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1900,
#           "unit": "K"
#         },
#         "length": {
#           "value": 11.451596396632992,
#           "unit": "m"
#         }
#       },
#       {
#         "temperature": {
#           "value": 1950,
#           "unit": "K"
#         },
#         "length": {
#           "value": 32.82117606229435,
#           "unit": "m"
#         }
#       }
#     ]
#   }
# }

# %%
#Save DataModelDict as xml file by setting fp = file-like object
with open('model.xml', 'w') as f:
    model.xml(fp=f)

#Print the DataModelDict as an xml string. 
#Setting an indent value adds newlines and line indentations
print model.xml(indent=4)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <my-data-model>
#     <name>Demo</name>
#     <author>Me</author>
#     <process>
#         <Instrument>
#             <Name>Shiny Thing</Name>
#             <Model>Newest Most Expensive</Model>
#         </Instrument>
#         <method>By the book</method>
#     </process>
#     <measurement>
#         <temperature>
#             <value>0</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>0.0</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>50</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>0.39986098996123576</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>100</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>0.7350887664271208</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>150</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>2.6241863863073105</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>200</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>2.7821708998501165</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>250</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>4.726741077367031</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>300</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>5.739600147226294</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>350</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>1.3136992202639524</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>400</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>3.775478992818595</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>450</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>1.6292075498700629</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>500</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>8.937033340067753</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>550</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>10.746507110396685</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>600</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>8.242033341633316</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>650</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>10.567668172212647</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>700</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>12.305571507602233</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>750</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>1.4502698012872686</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>800</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>4.033322751927717</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>850</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>7.355261000046035</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>900</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>13.79692538142339</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>950</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>16.062783315621484</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1000</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>9.678916059061535</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1050</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>15.08799736159959</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1100</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>1.3465121728657292</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1150</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>4.697804719217939</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1200</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>9.54570938141391</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1250</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>13.736695437676387</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1300</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>2.954255730222946</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1350</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>26.595459851374873</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1400</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>4.791723128290514</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1450</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>17.289926505564623</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1500</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>8.985074753494507</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1550</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>4.253037162747188</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1600</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>22.12879115480489</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1650</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>22.175456114239356</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1700</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>24.200213745881808</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1750</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>5.684011678165808</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1800</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>8.930905362572705</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1850</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>1.763515667806887</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1900</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>11.451596396632992</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
#     <measurement>
#         <temperature>
#             <value>1950</value>
#             <unit>K</unit>
#         </temperature>
#         <length>
#             <value>32.82117606229435</value>
#             <unit>m</unit>
#         </length>
#     </measurement>
# </my-data-model>

# %% [markdown]
# ##3. Loading Data Models
#
# DataModelDict has a load() method that reads in a string or file-like object in either xml or json format. The class initilizer also calls load() if the argument is a string or file-like object.

# %%
#load from xml file by initilizing new model
with open('model.xml') as f:
    model2 = DataModelDict(f)
    
#test that models are equivalent
print model.json() == model2.json() and model.xml()  == model2.xml()
# Out:
# True

# %%
#load from json file by using load()
model2 = DataModelDict()
with open('model.json') as f:
    model2.load(f)
    
#test that models are equivalent
print model.json() == model2.json() and model.xml()  == model2.xml()
# Out:
# True

# %%
#load from json string by initilizing new model
json_string = model.json()
model2 = DataModelDict(json_string)
    
#test that models are equivalent
print model.json() == model2.json() and model.xml()  == model2.xml()
# Out:
# True

# %%
#load from xml string by using load()
xml_string = model.xml()
model2 = DataModelDict()       
model2.load(xml_string)

#test that models are equivalent
print model.json() == model2.json() and model.xml()  == model2.xml()
# Out:
# True

# %% [markdown]
# ##4. Finding and Accessing Elements
#
# A number of methods have been added to DataModelDict to assist in finding, accessing, and modifying the various elements and subelements of a data model.

# %% [markdown]
# ###4.1 Index with path lists
#
# Normally, accessing or setting the values contained in a data model consisting of tiered dictionaries and lists requires knowing the full path list beforehand.  This can be tedious and requires that the programmer hard-code the absolute path of any elements of interest.  To improve upon this, values contained in a DataModelDict can be accessed using a _path list_ consisting of a list of indicies.  The terms in the list can be either dictionary keys or list indicies.

# %%
#Use indexing to retrieve the instrument name in the standard way
print model['my-data-model']['process']['Instrument']['Name']

#Use path list indexing to retrieve the instrument name
path = ['my-data-model', 'process', 'Instrument', 'Name']
print model[path]
# Out:
# Shiny Thing
# Shiny Thing

# %% [markdown]
# ###4.2 Find value(s) with key
#
# If you know the key for an element you are interested in but don't know where it is located in the data model, you can access the element's value using the find() and finds() methods.  find() will return a value if the search produces a unique result, and issue an error if no match or multiple matches are found.  finds() returns a list of all values obtained by the search conditions.

# %%
#I know the instrument name is the only element with the key Name
print model.find('Name')
# Out:
# Shiny Thing

# %%
#I want a list of all the measurement elements
measurements = model.finds('measurement')

print len(measurements), "measurements found, with first measurement being:"
print measurements[0].json(indent=2)
# Out:
# 40 measurements found, with first measurement being:
# {
#   "temperature": {
#     "value": 0,
#     "unit": "K"
#   },
#   "length": {
#     "value": 0.0,
#     "unit": "m"
#   }
# }

# %% [markdown]
# Both find() and finds() allow for additional search conditions using dictionary arguments _yes_ and _no_.  Any key-value pairs listed in _yes_ must be found in the element in order for it to be considered a match.  If any key-value pairs listed in _no_ are found in the element, then it is rejected.

# %%
#I want only the length from the measurement with temperature equal to 1750  
temp = DataModelDict([('value',1750), ('unit', 'K')])

print model.find('measurement', yes={'temperature':temp})['length']['value']

#I want all measurements except for when temperature equals 900
temp = DataModelDict([('value',900), ('unit', 'K')])

measurements = model.finds('measurement', no={'temperature':temp})
print len(measurements), "measurements found"
# Out:
# 5.68401167817
# 39 measurements found

# %% [markdown]
# ###4.3 Find path(s) with key
#
# Alternatively, if you want to learn the full path to any elements in unknown locations, you can use the path() and paths() methods.  These behave similarly to find() and finds(), but return path lists instead of values.

# %%
#I know the instrument name is the only element with the key Name
path = model.path('Name')
print path
print model[path]
# Out:
# ['my-data-model', 'process', 'Instrument', 'Name']
# Shiny Thing

# %% [markdown]
# The path() and paths() methods also allow for yes and no dictionaries to be used as arguments.

# %%
measurement_paths = model.paths('measurement', no={'temperature':temp})
for path in measurement_paths:
    print path
# Out:
# ['my-data-model', 'measurement', 0]
# ['my-data-model', 'measurement', 1]
# ['my-data-model', 'measurement', 2]
# ['my-data-model', 'measurement', 3]
# ['my-data-model', 'measurement', 4]
# ['my-data-model', 'measurement', 5]
# ['my-data-model', 'measurement', 6]
# ['my-data-model', 'measurement', 7]
# ['my-data-model', 'measurement', 8]
# ['my-data-model', 'measurement', 9]
# ['my-data-model', 'measurement', 10]
# ['my-data-model', 'measurement', 11]
# ['my-data-model', 'measurement', 12]
# ['my-data-model', 'measurement', 13]
# ['my-data-model', 'measurement', 14]
# ['my-data-model', 'measurement', 15]
# ['my-data-model', 'measurement', 16]
# ['my-data-model', 'measurement', 17]
# ['my-data-model', 'measurement', 19]
# ['my-data-model', 'measurement', 20]
# ['my-data-model', 'measurement', 21]
# ['my-data-model', 'measurement', 22]
# ['my-data-model', 'measurement', 23]
# ['my-data-model', 'measurement', 24]
# ['my-data-model', 'measurement', 25]
# ['my-data-model', 'measurement', 26]
# ['my-data-model', 'measurement', 27]
# ['my-data-model', 'measurement', 28]
# ['my-data-model', 'measurement', 29]
# ['my-data-model', 'measurement', 30]
# ['my-data-model', 'measurement', 31]
# ['my-data-model', 'measurement', 32]
# ['my-data-model', 'measurement', 33]
# ['my-data-model', 'measurement', 34]
# ['my-data-model', 'measurement', 35]
# ['my-data-model', 'measurement', 36]
# ['my-data-model', 'measurement', 37]
# ['my-data-model', 'measurement', 38]
# ['my-data-model', 'measurement', 39]

# %% [markdown]
# ##5. Treatment of Unbounded Sequences
#
# When converting from XML there is some ambiguity associated with sequences.  The normal parsing method will convert sequences with one element to single values, and sequences with multiple elements to lists.  To help with this, DataModelDict has a couple methods that allow for the handling of elements that may or may not be lists.
#
# The append() method allows for a key-value pair to be added to the DataModelDict.  If the key doesn't already exist, then it is assigned like a regular dictionary.  If the key does exist, the current value is converted into a list if it isn't one and the new value is appended.
#
# The aslist() method returns the value(s) associated with a dictionary key as a list, even if it isn't one.

# %%
#Check element value and aslist before key is assigned
print "model['my-data-model'].get('ordinal', None) ->", 
print model['my-data-model'].get('ordinal', None) 
print "model['my-data-model'].aslist('ordinal') ->   ", 
print model['my-data-model'].aslist('ordinal') 
print 

#append a value and check again
print "model['my-data-model'].append('ordinal', 'first')"
model['my-data-model'].append('ordinal', 'first')
print "model['my-data-model'].get('ordinal', None) ->", 
print model['my-data-model'].get('ordinal', None) 
print "model['my-data-model'].aslist('ordinal') ->   ", 
print model['my-data-model'].aslist('ordinal') 
print 

#append a value and check again
print "model['my-data-model'].append('ordinal', 'second')"
model['my-data-model'].append('ordinal', 'second')
print "model['my-data-model'].get('ordinal', None) ->", 
print model['my-data-model'].get('ordinal', None) 
print "model['my-data-model'].aslist('ordinal') ->   ", 
print model['my-data-model'].aslist('ordinal') 
print 

#append a value and check again
print "model['my-data-model'].append('ordinal', 'third')"
model['my-data-model'].append('ordinal', 'third')
print "model['my-data-model'].get('ordinal', None) ->", 
print model['my-data-model'].get('ordinal', None) 
print "model['my-data-model'].aslist('ordinal') ->   ", 
print model['my-data-model'].aslist('ordinal')
# Out:
# model['my-data-model'].get('ordinal', None) -> None
# model['my-data-model'].aslist('ordinal') ->    []
#
# model['my-data-model'].append('ordinal', 'first')
# model['my-data-model'].get('ordinal', None) -> first
# model['my-data-model'].aslist('ordinal') ->    ['first']
#
# model['my-data-model'].append('ordinal', 'second')
# model['my-data-model'].get('ordinal', None) -> ['first', 'second']
# model['my-data-model'].aslist('ordinal') ->    ['first', 'second']
#
# model['my-data-model'].append('ordinal', 'third')
# model['my-data-model'].get('ordinal', None) -> ['first', 'second', 'third']
# model['my-data-model'].aslist('ordinal') ->    ['first', 'second', 'third']

# %% [markdown]
# File removal to keep Notebook directory clean.

# %%
os.remove('model.json')
os.remove('model.xml')
